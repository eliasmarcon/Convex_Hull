# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
resultsQuickHull = pd.read_csv('../../test_csv_files/Testfile_Quickhull.csv')
resultsQuickHull
# Out:
#     Test_Case  Number_of_Points  Execution Time
# 0           1                 1          0.0000
# 1           2                10          0.0000
# 2           3               100          0.0000
# 3           4              1000          0.0000
# 4           5             10000          0.0031
# 5           6            100000          0.1094
# 6           7            250000          0.3606
# 7           8            500000          1.0195
# 8           9           1000000          2.2666
# 9          10           2500000          5.7448
# 10         11           5000000         10.0187
# 11         12          10000000         24.5101
# 12         13          25000000         62.0894
# 13         14          50000000        146.8821
# 14         15          75000000        214.9291
# 15         16         100000000       1890.3016

# %%
resultsGiftWrapping = pd.read_csv('../../test_csv_files/Testfile_GiftWrapping.csv')
resultsGiftWrapping
# Out:
#     Test_Case  Number_of_Points  Execution Time
# 0           1                 1          0.0011
# 1           2                10          0.0000
# 2           3               100          0.0000
# 3           4              1000          0.0160
# 4           5             10000          0.2528
# 5           6            100000          2.7311
# 6           7            250000          8.0709
# 7           8            500000         20.5345
# 8           9           1000000         41.8525
# 9          10           2500000         89.8024
# 10         11           5000000        201.3337
# 11         12          10000000        422.8751
# 12         13          25000000       1199.1316
# 13         14          50000000       2293.9793
# 14         15          75000000       3328.5747
# 15         16         100000000       4460.9375

# %%
# Quickhull expand function, compare to O(n log n)
#wtf
x = np.array(resultsQuickHull['Number_of_Points'])
y = np.array(resultsQuickHull['Execution Time'])
coeffs = np.polyfit(x, y, 2)
y_pred = np.polyval(coeffs, x)
plt.scatter(x,y)
n = np.linspace(1, 100, 100000000)
y2 = n * np.log(n)
plt.plot(n, y2)

plt.show()
